# %%
import pandas as pd
import numpy as np
import pandas_datareader as web
import yfinance as yf
import matplotlib.pyplot as plt
import mplfinance as mpf
import seaborn as sns
import datetime as dt

# %%
TICKER = "KINV-B.ST"
START = "2015-01-01"
END = "2022-01-09"

# %%
df = web.DataReader(TICKER, "yahoo", START, END)

# %%
df.head()
# Out:
#                   High         Low        Open       Close     Volume   Adj Close
# Date
# 2015-01-02  244.979584  242.225937  242.890610  243.270416   384316.0  194.202286
# 2015-01-05  244.884628  241.941071  242.890610  242.225937   182127.0  193.368484
# 2015-01-07  239.282379  228.742554  238.427795  229.597137  1055454.0  183.286926
# 2015-01-08  236.908554  230.071915  232.160873  236.623688   732099.0  188.896240
# 2015-01-09  237.288361  232.350784  235.674149  233.395279   545706.0  186.318985

# %%
plt.figure(figsize=(12, 6))

sns.lineplot(x=df.index, y="Adj Close", data=df)
sns.lineplot(data=avg_30["2021-10-01":])

plt.show()

# %%
avg_30 = df["Adj Close"].rolling(30).mean()

# %%
FROM_DATE = "2021-12-01"
TO_DATE = dt.date.today()

adp = mpf.make_addplot(avg_30[FROM_DATE:], type="line")

fig, axes = mpf.plot(df[FROM_DATE:],
         type="candle",
         title = f"{TICKER} Adjusted Closing Price\n{FROM_DATE} - {TO_DATE}",
         style="yahoo",
         figscale=1,
         figsize=(12, 6),
         addplot = adp,
         returnfig=True
        )
axes[0].legend(["30 day average"])
# axes[1].legend(["test1"])
# axes.legend(["Test", "Test2"])
plt.show()

# %%
axes
